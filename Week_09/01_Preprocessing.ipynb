# %% [markdown]
# # Preprocessing - classificatie van nieuwsartikelen
#
# In deze notebook gaan we nieuwsartikelen classificeren. Om dit met pytorch zelf te doen heb je wat meer manueel preprocessing om de tokenization zelf te doen. Voor het berekenen van de embedding kan wel een standaard laag gebruikt worden.

# %%
# Import necessary libraries
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import pandas as pd
from collections import Counter
import re
import kagglehub

# %% [markdown]
# ## Data inladen - Nieuwsberichten
#
# We gebruiken de AG_NEWS dataset die gedownload kan worden van kaggle met deze link: https://www.kaggle.com/datasets/amananandrai/ag-news-classification-dataset

# %%
path = kagglehub.dataset_download("amananandrai/ag-news-classification-dataset")

# %% [markdown]
# ## Preprocessing - tokenizer

# %%
# Parameters
MAX_NUM_WORDS = 20000  # Maximum number of unique words to keep
MAX_SEQUENCE_LENGTH = 50  # Maximum length of input sequences

# %% [markdown]
# ## Neuraal netwerk met embedding

# %%
EMBEDDING_DIM = 100
